# %% [markdown]
# # 02_Expertise_Analysis.ipynb: My Bachelor's Degree Expertise
#
# ## Business Administration and Engineering: Electrical Power Engineering (B.Sc. RWTH)
#
# In this notebook I look at the modules I completed during my Bachelor's degree and explain how they built the practical knowledge I use every day as an electrical engineer at Deutsche Bahn InfraGO AG.
#
# The degree gave me a balanced foundation: strong technical skills in power systems and electrical engineering, combined with business and economic understanding. This combination is especially useful for the challenges of renewable energy integration, smart grids, and secure infrastructure.

# %%
import pandas as pd
import os

# Define path to the structured metadata
BASE_PATH = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
KEY_DETAILS_CSV = os.path.join(BASE_PATH, 'data', 'key_details.csv')

# Load the key details
key_details_df = pd.read_csv(KEY_DETAILS_CSV)

print("My Module Groups and Average Grades")
print("=" * 50)
groups = key_details_df[key_details_df['section'].str.contains('Module Group', case=False)]
print(groups[['detail_key', 'detail_value']].to_string(index=False))

print("\nSelected Key Modules with Grades")
key_modules = key_details_df[key_details_df['section'] == 'Key Module']
print(key_modules[['detail_key', 'detail_value']].to_string(index=False))

# %% [markdown]
# ### How My Studies Connect to My Daily Work
#
# My engineering modules gave me the technical foundation I need for power systems and infrastructure:
# - Electrical fundamentals, circuit analysis, signals & systems, and power supply components (average 3.5)
# - Power systems planning and operation
#
# The business and economics modules taught me how to evaluate projects from a cost, market, and organisational perspective (average 3.8).
#
# My Bachelor thesis (grade 3.0) focused on a cross-domain knowledge base for cyber intelligence in smart grids. This directly supports the IT safety and modernisation work I do at Deutsche Bahn InfraGO AG.
#
# The combination of these areas helps me contribute to:
# - Secure integration of renewable energy into rail infrastructure
# - Reliable and resilient power supply for stations
# - Compliance with safety and IT guidelines (Ril)
# - Modernisation projects that balance technical feasibility with economic and sustainability goals

# %%
# Summary of core expertise areas from my degree
expertise = key_details_df[key_details_df['section'] == 'Key Facts']
print("\nCore Expertise Areas from My Degree")
print(expertise[['detail_key', 'detail_value']].to_string(index=False))

print("\n\nAll of these topics are directly applied in my current role at Deutsche Bahn InfraGO AG.")
